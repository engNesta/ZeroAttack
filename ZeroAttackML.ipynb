# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
# Robel, you can add your paths below instead:
file_1_path = '/Users/nesta99/Desktop/ML/ZeroAttack/dataset/zero_day_attack_detection_dataset_V1-400k.csv'
file_2_path = '/Users/nesta99/Desktop/ML/ZeroAttack/dataset/zero_day_attack_detection_dataset_V2_97k.csv'
dataset1 = pd.read_csv(file_1_path)
dataset2 = pd.read_csv(file_2_path)


# Display the first few rows to ensure the dataset is loaded correctly
dataset2.head()
# Out:
#                   Time Protocol Flag  Family  Clusters      SeddAddress  \
# 0  2022-06-25 15:27:14      UDP  FIN  Normal         3    160.84.213.77
# 1  2023-11-25 06:31:11      UDP  SYN  Normal         2    49.156.26.103
# 2  2023-09-10 23:58:40      UDP  ACK  Normal         2   123.239.195.30
# 3  2021-11-06 14:50:17      UDP  ACK  Normal         5  138.249.125.144
# 4  2023-08-22 08:42:04      TCP  SYN  Normal         5    14.249.225.22
#
#        ExpAddress   BTC     USD  Netflow Bytes  ... Application Layer Data  \
# 0  32.249.232.174  0.65  485.98           2351  ...            GET /status
# 1     189.4.42.24  0.13  805.71           7268  ...           POST /upload
# 2  129.31.125.171  0.85  487.17           1418  ...           POST /upload
# 3  180.10.227.228  0.01  368.87           9486  ...            GET /status
# 4   98.118.94.201  0.50  661.63           7507  ...           POST /upload
#
#     User-Agent  Geolocation Logistics ID  Anomaly Score   Event Description  \
# ...
